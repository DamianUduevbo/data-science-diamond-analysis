# %% [markdown]
# ## PHASE 1:
# Loading the attached data into a pandas dataframe from diamonds.csv.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

df = pd.read_csv('diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# ## PHASE 2:
# Selecting any two variables and explaining its statistical summary, e.g. mean, median, min, max, etc using the .describe() method.

# %%
cols = df[['carat', 'price']]

stat_summ = cols.describe()
stat_summ
# Out:
#               carat         price
# count  53940.000000  53940.000000
# mean       0.797940   3932.799722
# std        0.474011   3989.439738
# min        0.200000    326.000000
# 25%        0.400000    950.000000
# 50%        0.700000   2401.000000
# 75%        1.040000   5324.250000
# max        5.010000  18823.000000

# %% [markdown]
# Carat:
# * **Count**: There are 53,940 non-null entries in the "carat" column.
# * **Mean**: The average carat weight of the diamonds in the dataset is approximately 0.798 carats.
# * **Std**: The standard deviation is approximately 0.474, indicating that carat weights vary around the mean.
# * **Min**: The minimum carat weight in the dataset is 0.20 carats.
# * **25%**: The first quartile is 0.40 carats, meaning 25% of the diamonds have a carat weight less than or equal to 0.40 carats.
# * **50%**: The second quartile is 0.70 carats, meaning 50% of the diamonds have a carat weight less than or equal to 0.70 carats.
# * **75%**: The third quartile is 1.04 carats, indicating that 75% of the diamonds have a carat weight less than or equal to 1.04 carats.
# * **Max**: The maximum carat weight in the dataset is 5.01 carats.
#
# Price:
# * **Count**: There are 53,940 non-null entries in the "price" column.
# * **Mean**: The average price of the diamonds in the dataset is approximately `$`3932.80.
# * **Std**: The standard deviation is approximately `$`3989.44, indicating that diamond prices have a relatively wide range of values.
# * **Min**: The minimum price in the dataset is `$`326.
# * **25%**: The first quartile is `$`950, meaning 25% of the diamonds have a price less than or equal to `$`950.
# * **50%**: The second quartile is `$`2401, meaning 50% of the diamonds have a price less than or equal to `$`2401.
# * **75%**: The third quartile is `$`5324.25, indicating that 75% of the diamonds have a price less than or equal to `$`5324.25.
# * **Max**: The maximum price in the dataset is `$`18823.

# %% [markdown]
# ## PHASE 3:
# Creating a bar chart that shows the frequency of diamonds grouped by cut.

# %%
cut_counts = df['cut'].value_counts()

# Create a bar chart
plt.figure(figsize=(8, 6))
cut_counts.plot(kind='bar', color='skyblue')

plt.title('Frequency of Diamonds by Cut')
plt.xlabel('Cut')
plt.ylabel('Frequency')
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# Ideal Cut (20000+): The "Ideal" cut is the most frequent category, with an estimated count of over 20,000 diamonds. This suggests that a significant number of diamonds in the dataset have an "Ideal" cut, which is often associated with the highest quality and precision in terms of cut, symmetry, and proportions.
#
# Premium Cut (~14000): The "Premium" cut is the second most frequent category, with an estimated count of around 14,000 diamonds. "Premium" diamonds are also known for their high-quality cut, but they may have some variations compared to "Ideal" diamonds, often making them more affordable while maintaining good quality.
#
# Very Good Cut (~13000): The "Very Good" cut is close in frequency to the "Premium" cut, with an estimated count of around 13,000 diamonds. "Very Good" diamonds are known for having a very attractive balance between quality and price, making them a popular choice.
#
# Good Cut (5000): The "Good" cut has an estimated count of 5,000 diamonds. While these diamonds may not exhibit the same level of brilliance as those with higher cut grades, they can still offer a good balance between quality and affordability.
#
# Fair Cut (~1000): The "Fair" cut is the least frequent category, with an estimated count of around 1,000 diamonds. Diamonds with a "Fair" cut may have noticeable imperfections in their cut, which can affect their overall appearance and value.

# %% [markdown]
# The chart indicates the distribution of diamonds in the dataset across different cut categories. It shows that a substantial number of diamonds fall into the "Ideal" and "Premium" cut categories, while the "Fair" cut is the least common. The choice of cut can significantly impact a diamond's appearance and price, so this information is valuable for understanding the characteristics of the diamonds in your dataset.

# %% [markdown]
# ## PHASE 4:
# Creating a scatterplot that shows the relationship between carat and price.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['carat'], df['price'], alpha=0.5, color='green', marker='o')

plt.title('Scatterplot of Carat vs. Price')
plt.xlabel('Carat')
plt.ylabel('Price')

plt.xlim(0, 3)
plt.ylim(0, 8538)


plt.show()

# %% [markdown]
# The chart shows the relationship between Carat value and Price. There appears to be a strong positive relation between carat and price, therefore the higher the carat, the higher the price.

# %% [markdown]
# ## PHASE 5:
# Calculating the Pearson Correlation coefficient of carat and price.

# %%
df['carat'].corr(df['price'], method='pearson')
# Out:
# 0.9215913011934771

# %% [markdown]
# The result shows a strong positive correlation between carat and price. As the carat increases, the price increases as well.

# %% [markdown]
# ## PHASE 6:
# Creating seperate histograms that shows the distribution of prices based on the quality of the cut for each cut.

# %%
cut_categories = df['cut'].unique()

# %%
plt.hist(df[df['cut'] == 'Ideal']['price'], bins=30, alpha=0.5, label=cut_category)
plt.title('Price Distribution by Cut')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Chart is a skewed right (positive), where cheaper 'Ideal' cuts appear more frequently than expensive ones.

# %%
plt.hist(df[df['cut'] == 'Premium']['price'], bins=30, alpha=0.5, label=cut_category)
plt.title('Price Distribution by Cut')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Chart is a skewed right (positive), where cheaper 'Premium' cuts appear more frequently than expensive ones.

# %%
plt.hist(df[df['cut'] == 'Very Good']['price'], bins=30, alpha=0.5, label=cut_category)
plt.title('Price Distribution by Cut')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Chart is a skewed right (positive), where cheaper 'Very Good' cuts appear more frequently than expensive ones.

# %%
plt.hist(df[df['cut'] == 'Good']['price'], bins=30, alpha=0.5, label=cut_category)
plt.title('Price Distribution by Cut')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Chart is a skewed right (positive), where cheaper 'Good' cuts appear more frequently than expensive ones.

# %%
plt.hist(df[df['cut'] == 'Fair']['price'], bins=30, alpha=0.5, label=cut_category)
plt.title('Price Distribution by Cut')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Chart is a skewed right (positive), where cheaper 'Fair' cuts appear more frequently than expensive ones.

# %% [markdown]
# ## PHASE 7:
# Using a 2-sample t-test to determine if there is a statistical difference between the price of diamonds with a cut that is considered:
# * 'Good' vs 'Very Good'
# * 'Premium' vs 'Ideal'
# * set alpha to 5% i.e. 0.05.

# %%
price_good = df[df['cut'] == 'Good']['price']
price_very_good = df[df['cut'] == 'Very Good']['price']
price_premium = df[df['cut'] == 'Premium']['price']
price_ideal = df[df['cut'] == 'Ideal']['price']

alpha = 0.05

# 'Good' vs 'Very Good'
t_stat_goodness, p_value_goodness = stats.ttest_ind(price_good, price_very_good)

if p_value_goodness < alpha:
  print("The price of 'Good' and 'Very Good' cuts is statistically different.")
else:
  print("The price of 'Good' and 'Very Good' cuts is not statistically different.")

# 'Premium' vs 'Ideal'
t_stat_prem, p_value_premium = stats.ttest_ind(price_premium, price_ideal)
if p_value_premium < alpha:
  print("The price of 'Premium' and 'Ideal' cuts is statistically different.")
else:
  print("The price of 'Premium' and 'Ideal' cuts is not statistically different.")
# Out:
# The price of 'Good' and 'Very Good' cuts is not statistically different.
# The price of 'Premium' and 'Ideal' cuts is statistically different.
